# %%
"https://nbviewer.jupyter.org/github/CamDavidsonPilon/Probabilistic-Programming-and-Bayesian-Methods-for-Hackers/blob/master/Chapter1_Introduction/Ch1_Introduction_PyMC3.ipynb"
# Out:
# 'https://nbviewer.jupyter.org/github/CamDavidsonPilon/Probabilistic-Programming-and-Bayesian-Methods-for-Hackers/blob/master/Chapter1_Introduction/Ch1_Introduction_PyMC3.ipynb'

# %%
# %matplotlib inline
from IPython.core.pylabtools import figsize
import numpy as np
from matplotlib import pyplot as plt
figsize(11,9)
import scipy.stats as stats

# %%
dist = stats.beta
n_trials = [0, 1, 2, 3, 4, 5, 8, 15, 50, 500]
data = stats.bernoulli.rvs(0.5, size = n_trials[-1])
nrows = len(n_trials)/2
ncols = 2
x = np.linspace(0, 1 , 100)

for k, N in enumerate(n_trials):

    sx = plt.subplot(nrows, ncols, k + 1)
    plt.xlabel("$p$, probability of heads") \
        if k in [0, len(n_trials) - 1] else None
    plt.setp(sx.get_yticklabels(), visible=False)
    heads = data[:N].sum()
    y = dist.pdf(x, 1 + heads, 1 + N - heads)
    plt.plot(x, y, label=f"observe {N} tosses, \n {heads} heads")
    plt.fill_between(x, 0, y, color="#348ABD", alpha=0.4)
    plt.vlines(0.5, 0, 4, color="k", linestyles="--", lw=1)
    plt.fill_between(x, 0, y, color="#348ABD", alpha=0.4)
    plt.vlines(0.5, 0, 4, color="k",linestyle="--", lw=1)
    
    leg = plt.legend()
    leg.get_frame().set_alpha(0.4)
    plt.autoscale(tight=True)
    
plt.suptitle("Bayesian updating of posterior probabilities", y = 1.02, fontsize=14)
plt.tight_layout()

# %% [markdown]
# ## Poisson Distribution

# %%
a = np.arange(16)
poi = stats.poisson
lambda_ = [1.5, 4.26]
colours = ["#348ABD", "#A60628"]

plt.bar(a, poi.pmf(a, lambda_[0]), color=colours[0],
       label=f"$\lambda = lambda_[0]$" , alpha=0.6,
       edgecolor=colours[0],lw=3)

plt.bar(a, poi.pmf(a, lambda_[1]), color = colours[1],
       label=f"$\lambda = {lambda_[1]}$", alpha=0.6,
       edgecolor=colours[1],lw=3)

plt.xticks(a + 0.4, a)
plt.legend()
plt.ylabel("probability of $k$")
plt.xlabel("$k$")
plt.title("PMF of a Poisson random variable; differing \
$\lambda$ values")
# Out:
# Text(0.5, 1.0, 'PMF of a Poisson random variable; differing $\\lambda$ values')

# %% [markdown]
# ## Exponential Random Variable

# %%
a = np.linspace(0, 4, 100)
expo = stats.expon
lambda_ = [0.4, 1]

for l, c in zip(lambda_, colours):
    plt.plot(a, expo.pdf(a, scale=1. /l), lw=3,
            color=c, label=f"$\lambda$ = {l}")
    plt.fill_between(a, expo.pdf(a, scale=1./l), color=c, alpha=.33)
    
plt.legend()
plt.ylabel("PDF at $z$")
plt.xlabel("z")
plt.ylim(0, 1.2)
plt.title("Probability density function of an Exponential random variable;\
$\lambda$")
# Out:
# Text(0.5, 1.0, 'Probability density function of an Exponential random variable;$\\lambda$')
